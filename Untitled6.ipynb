# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
ECL = pd.read_csv("export1.csv", parse_dates=["REPORTING_DATE"], index_col="REPORTING_DATE")
ECL.head()
# Out:
#                STICHTAG_MANDANT_LAUF_RECHT_AN  CLIENT  KEY_RUN  \
# REPORTING_DATE
# 2019-09-30                19093002200AIFRSRCI    2200       57
# 2019-09-30                19093002200AIFRSRCI    2200       57
# 2019-09-30                19093002200AIFRSRCI    2200       57
# 2019-09-30                19093002200AIFRSRCI    2200       57
# 2019-09-30                19093002200AIFRSRCI    2200       57
#
#                KEY_REPORTING_REGULATION TRANSACTION_ID KEY_TRANSACTION_CAT  \
# REPORTING_DATE
# 2019-09-30                         IFRS  24036126_REPO                   R
# 2019-09-30                         IFRS  24037558_REPO                   R
# 2019-09-30                         IFRS  24038130_REPO                   R
# 2019-09-30                         IFRS  24081965_REPO                   R
# 2019-09-30                         IFRS  30374682_REPO                   R
#
#                GROUP_CONS_COMPANIES_ID KEY_SECURITISATION_VIEW  \
# REPORTING_DATE
# 2019-09-30                                                   B
# 2019-09-30                                                   B
# 2019-09-30                                                   B
# 2019-09-30                                                   B
# 2019-09-30                                                   B
#
#                KEY_PRIMARY_RISK_PARTNER  AGE  ... LGD_PR_UNCOL_IFRS_Y2  \
# REPORTING_DATE                                ...
# 2019-09-30                            P   98  ...                  0.0
# 2019-09-30                            P  144  ...                  0.0
# 2019-09-30                            P   91  ...                  0.0
# 2019-09-30                            P  110  ...                  0.0
# 2019-09-30                            P  395  ...                  0.0
#
#                LGD_PR_UNCOL_IFRS_Y3 ASSET_CLASS_TRANSACTION_IRB  \
# REPORTING_DATE
# 2019-09-30                      0.0                          BS
# 2019-09-30                      0.0                          BA
# 2019-09-30                      0.0                          BS
# 2019-09-30                      0.0                          BS
# 2019-09-30                      0.0                          BA
#
#                 IME_TRANS_CLUSTER_ID THRESHOLD_PD_ADJUSTED  FLAG_PRIVATI_LIKE  \
# REPORTING_DATE
# 2019-09-30           24036126_REPO_R                   NaN                NaN
# 2019-09-30           24037558_REPO_R                   NaN                NaN
# 2019-09-30           24038130_REPO_R                   NaN                NaN
# 2019-09-30           24081965_REPO_R                   NaN                NaN
# 2019-09-30           30374682_REPO_R                   NaN                NaN
#
#                 SCONF_NO_FIDO  SEGMENTO_INTERNO  CALIB_DRIVER  \
# REPORTING_DATE
# 2019-09-30                NaN               NaN           NaN
# 2019-09-30                NaN               NaN           NaN
# 2019-09-30                NaN               NaN           NaN
# 2019-09-30                NaN               NaN           NaN
# 2019-09-30                NaN               NaN           NaN
#
#                 CLB_DRIVER_PRE_WS
# REPORTING_DATE
# 2019-09-30                    NaN
# 2019-09-30                    NaN
# 2019-09-30                    NaN
# 2019-09-30                    NaN
# 2019-09-30                    NaN
#
# [5 rows x 69 columns]

# %%
ECL.dropna(axis=1, how='any', inplace=True)

# %%
ECL["PARTNER_ID"] = ECL["PARTNER_ID"].astype(str)

# %%
ECL.loc["2020-03-31"]
# Out:
#                STICHTAG_MANDANT_LAUF_RECHT_AN  CLIENT  KEY_RUN  \
# REPORTING_DATE
# 2020-03-31                20033102200AIFRSRCI    2200       57
# 2020-03-31                20033102200AIFRSRCI    2200       57
# 2020-03-31                20033102200AIFRSRCI    2200       57
# 2020-03-31                20033102200AIFRSRCI    2200       57
# 2020-03-31                20033102200AIFRSRCI    2200       57
# ...                                       ...     ...      ...
# 2020-03-31                20033102200AIFRSRCI    2200       57
# 2020-03-31                20033102200AIFRSRCI    2200       57
# 2020-03-31                20033102200AIFRSRCI    2200       57
# 2020-03-31                20033102200AIFRSRCI    2200       57
# 2020-03-31                20033102200AIFRSRCI    2200       57
#
#                KEY_REPORTING_REGULATION                        TRANSACTION_ID  \
# REPORTING_DATE
# 2020-03-31                         IFRS                         24036126_REPO
# 2020-03-31                         IFRS                         24037558_REPO
# 2020-03-31                         IFRS                         24038130_REPO
# 2020-03-31                         IFRS                         24081965_REPO
# 2020-03-31                         IFRS                         30374682_REPO
# ...                                 ...                                   ...
# 2020-03-31                         IFRS  NO_CURRENT__100000011_1000000_11_CHF
# 2020-03-31                         IFRS  NO_CURRENT__100000011_1000000_11_EUR
# 2020-03-31                         IFRS  NO_CURRENT__100000011_1000000_11_JPY
# 2020-03-31                         IFRS  NO_CURRENT__100000011_1000000_11_USD
# 2020-03-31                         IFRS  NO_CURRENT__100000050_1000289_51_EUR
#
#                KEY_TRANSACTION_CAT GROUP_CONS_COMPANIES_ID  \
# REPORTING_DATE
# 2020-03-31                       R
# 2020-03-31                       R
# 2020-03-31                       R
# 2020-03-31                       R
# 2020-03-31                       R
# ...                            ...                     ...
# 2020-03-31                       N
# 2020-03-31                       N
# 2020-03-31                       N
# 2020-03-31                       N
# 2020-03-31                       N
#
#                KEY_SECURITISATION_VIEW KEY_PRIMARY_RISK_PARTNER  AGE  ...  \
# REPORTING_DATE                                                        ...
# 2020-03-31                           B                        P   64  ...
# 2020-03-31                           B                        P   62  ...
# 2020-03-31                           B                        P   67  ...
# 2020-03-31                           B                        P  169  ...
# 2020-03-31                           B                        P  -14  ...
# ...                                ...                      ...  ...  ...
# 2020-03-31                           B                        P    0  ...
# 2020-03-31                           B                        P    0  ...
# 2020-03-31                           B                        P    0  ...
# 2020-03-31                           B                        P    0  ...
# 2020-03-31                           B                        P    0  ...
#
#                KEY_ID_SAP PRODUCT_IDENTIFICATION_ID  KEY_PRODUCT  \
# REPORTING_DATE
# 2020-03-31                              12-24-02-01  12-XX-XX-XX
# 2020-03-31                              12-24-02-01  12-XX-XX-XX
# 2020-03-31                              12-24-02-01  12-XX-XX-XX
# 2020-03-31                              12-24-02-01  12-XX-XX-XX
# 2020-03-31                              12-21-01-03  12-XX-XX-XX
# ...                   ...                       ...          ...
# 2020-03-31                              01-01-01-13  01-01-01-13
# 2020-03-31                              01-01-01-13  01-01-01-13
# 2020-03-31                              01-01-01-13  01-01-01-13
# 2020-03-31                              01-01-01-13  01-01-01-13
# 2020-03-31                              01-01-01-13  01-01-01-13
#
#                PD_PR_IFRS_Y1  LGD_PR_UNCOL_IFRS_Y1  PD_PR_IFRS_Y2  \
# REPORTING_DATE
# 2020-03-31          0.001796              0.331120            0.0
# 2020-03-31          0.001379              0.327244            0.0
# 2020-03-31          0.005770              0.426403            0.0
# 2020-03-31          0.001053              0.410909            0.0
# 2020-03-31          0.004349              0.448352            0.0
# ...                      ...                   ...            ...
# 2020-03-31          0.004349              0.448352            0.0
# 2020-03-31          0.004349              0.448352            0.0
# 2020-03-31          0.004349              0.448352            0.0
# 2020-03-31          0.004349              0.448352            0.0
# 2020-03-31          0.003028              0.306602            0.0
#
#                 PD_PR_IFRS_Y3  LGD_PR_UNCOL_IFRS_Y2  LGD_PR_UNCOL_IFRS_Y3  \
# REPORTING_DATE
# 2020-03-31                0.0                   0.0                   0.0
# 2020-03-31                0.0                   0.0                   0.0
# 2020-03-31                0.0                   0.0                   0.0
# 2020-03-31                0.0                   0.0                   0.0
# 2020-03-31                0.0                   0.0                   0.0
# ...                       ...                   ...                   ...
# 2020-03-31                0.0                   0.0                   0.0
# 2020-03-31                0.0                   0.0                   0.0
# 2020-03-31                0.0                   0.0                   0.0
# 2020-03-31                0.0                   0.0                   0.0
# 2020-03-31                0.0                   0.0                   0.0
#
#                                   IME_TRANS_CLUSTER_ID
# REPORTING_DATE
# 2020-03-31                             24036126_REPO_R
# 2020-03-31                             24037558_REPO_R
# 2020-03-31                             24038130_REPO_R
# 2020-03-31                             24081965_REPO_R
# 2020-03-31                             30374682_REPO_R
# ...                                                ...
# 2020-03-31      NO_CURRENT__100000011_1000000_11_CHF_N
# 2020-03-31      NO_CURRENT__100000011_1000000_11_EUR_N
# 2020-03-31      NO_CURRENT__100000011_1000000_11_JPY_N
# 2020-03-31      NO_CURRENT__100000011_1000000_11_USD_N
# 2020-03-31      NO_CURRENT__100000050_1000289_51_EUR_N
#
# [212 rows x 54 columns]

# %%
fig, ax = plt.subplots()
ax.plot(ECL.index, ECL["EAD1Y"], color="red")
ax.set_ylabel("EAD", color="red")
ax.set_xticklabels(ECL.index, rotation=90)
ax.tick_params("y", colors="red")
ax2 = ax.twinx()
ax2.plot(ECL.index, ECL["EXPECTED_LOSS_1Y"], color="blue")
ax2.set_xlabel("Time")
ax2.set_ylabel("Expected Loss", color="blue")
ax2.tick_params("y", colors="blue")
ax2.annotate("Covid Impact", xy=(pd.Timestamp("2020-03-31"), 1000000), xytext=(pd.Timestamp("2020-01"),800000),
            arrowprops={})
# Out:
# <ipython-input-73-6f094846be8c>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ECL.index, rotation=90)
# Text(2020-01-01 00:00:00, 800000, 'Covid Impact')

# %%
fig, ax2 = plt.subplots()
ax2.plot(ECL.index, ECL["EXPECTED_LOSS_1Y"], color="blue")
ax2.set_xlabel("Time")
ax2.set_ylabel("Expected Loss", color="blue")
ax2.tick_params("y", colors="blue")
ax2.annotate("Covid Impact", xy=(pd.Timestamp("2020-03-31"), 1000000), xytext=(pd.Timestamp("2020-01"),800000),
            arrowprops={})
# Out:
# Text(2020-01-01 00:00:00, 800000, 'Covid Impact')

# %%
fig, ax2 = plt.subplots(ncols=2)
ax2.plot(ECL.index, ECL["EXPECTED_LOSS_1Y"], color="blue")
ax2.set_xlabel("Time")
ax2.set_ylabel("Expected Loss", color="blue")
ax2.tick_params("y", colors="blue")
ax2.annotate("Covid Impact", xy=(pd.Timestamp("2020-03-31"), 1000000), xytext=(pd.Timestamp("2020-01"),800000),
            arrowprops={})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-8394432fe34d> in <module>
#       1 fig, ax2 = plt.subplots(ncols=2)
# ----> 2 ax2.plot(ECL.index, ECL["EXPECTED_LOSS_1Y"], color="blue")
#       3 ax2.set_xlabel("Time")
#       4 ax2.set_ylabel("Expected Loss", color="blue")
#       5 ax2.tick_params("y", colors="blue")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
fig, ax = plt.subplots()
ax.plot(ECL_Grouped.index, ECL_Grouped["EXPECTED_LOSS_1Y"], color="blue")
ax.set_xlabel("Time")
ax.set_ylabel("Expected Loss", color="blue")
ax.tick_params("y", colors="blue")
ax.annotate("Covid Impact", xy=(pd.Timestamp("2020-03-31"), 1000000), xytext=(pd.Timestamp("2020-01"),800000),
            arrowprops={})
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#
# C:\ProgramData\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648         if res is None:
# --> 649             raise ParserError("Unknown string format: %s", timestr)
#     650
#
# ParserError: Unknown string format: EXPECTED_LOSS_1Y
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     663             try:
# --> 664                 key = self._maybe_cast_for_get_loc(key)
#     665             except ValueError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in _maybe_cast_for_get_loc(self, key)
#     691         # needed to localize naive datetimes or dates (GH 35690)
# --> 692         key = Timestamp(key)
#     693         if key.tzinfo is None:
#
# pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# ValueError: could not convert string to Timestamp
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-692fcbf39dc3> in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.plot(ECL_Grouped.index, ECL_Grouped["EXPECTED_LOSS_1Y"], color="blue")
#       3 ax.set_xlabel("Time")
#       4 ax.set_ylabel("Expected Loss", color="blue")
#       5 ax.tick_params("y", colors="blue")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     664                 key = self._maybe_cast_for_get_loc(key)
#     665             except ValueError as err:
# --> 666                 raise KeyError(key) from err
#     667
#     668         elif isinstance(key, timedelta):
#
# KeyError: 'EXPECTED_LOSS_1Y'
